# %% [markdown]
# ### Basic global settings trials including ncluster, method and data used

# %%
import os
import json
import itertools
import pandas as pd
from functions import *
# %set_env GUROBI_HOME=/usr/local/gurobi/linux64
# Out:
# env: GUROBI_HOME=/usr/local/gurobi/linux64

# %%
with open('config.json', 'r') as f:
    config_all = json.loads(f.read())

config = config_all['Texas_7_years_1']
inputs = config['inputs']
settings = config['settings']
print(config)
pv_all = np.genfromtxt(
    os.path.join(config['root'], config['pv_path']), delimiter=',', filling_values=0)
wind_all = np.genfromtxt(
    os.path.join(config['root'], config['wind_path']), delimiter=',', filling_values=0)
load_all = np.genfromtxt(
    os.path.join(config['root'], config['load_path']), delimiter=',', filling_values=0)  # Data load
# Out:
# {'root': '/home/jupyter-zyh/Gnhe/data/Texas/', 'save_root': '/home/jupyter-zyh/Gnhe/analysis_setting/normalize/Integer/', 'pv_path': 'pv_data_Texas.csv', 'wind_path': 'wind_data_Texas.csv', 'load_path': 'power_demand_Texas.csv', 'note_1': 'This property is set to indicate what are above properties for path. No need to change.', 'inputs': {'c_bat': 200000, 'c_bat_power': 70000, 'c_pv': 1000000, 'c_wind': 1500000, 'c_gen_inv': 1000000, 'c_gen_a': 0.1, 'c_gen_b': 30, 'up_time': 6, 'down_time': 6, 'energy_cap': 200, 'power_cap': 200, 'gen_cap': 1, 'mdc': 50, 'effi': 0.9, 'rps': 0.8, 'note_2': 'This property is set to indicate what are above properties for model. Change with model parameters.', 'solver': 1, 'print_log': 0, 'timelimit': 210240, 'note_3': 'This property is set to indicate what are above properties for solver. No need to change.'}, 'settings': {'data': 'Texas', 'profile_id': 1, 'day_num': 1092, 'period': 168, 'normalize': True, 'feature_set': ['renewable_cap', 'N', 'max_energy', 'max_power', 'total_cost']}, 'note_4': 'This property is set to indicate what are above properties for settings. Change with data and method.', 'ranges': {'methods': ['kmeans', 'single', 'ward', 'average', 'complete'], 'trials': ['hourly', 'simulated', 'combined'], 'nclusters': [5, 10, 15, 20, 25, 30]}, 'note_5': 'This property is set to indicate what are above properties for global setings. Change with global settings.'}

# %%
day_num = settings['day_num']
time_set = np.arange(24*day_num)  # Time horizon
if 'profile_id' in settings:
    profile_id = settings['profile_id']
    renewable = [wind_all[time_set, profile_id],pv_all[time_set, profile_id]]
else:
    # Denote that first profile is used and no other profile exists.
    profile_id = -1
    renewable = [wind_all[time_set], pv_all[time_set]]
load = load_all[time_set]*100  # Data extract

# %%
for rps in [0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]:
    print("Rps :" + str(rps))
    inputs['rps'] = rps
    config['inputs'] = inputs
    expected = pd.read_csv('/home/jupyter-zyh/Gnhe/benchmark/Integer/Texas/profile-{}/expected/expected_1092_rps_{}_1e-3.csv'.format(profile_id,rps), index_col=0).loc[0,:].to_dict()
    sim_features_df = pd.read_csv('/home/jupyter-zyh/Gnhe/benchmark/Integer/Texas/profile-{}/features/features_1092_rps_{}_1e-3.csv'.format(profile_id,rps), index_col=0)
    df = run_trials(config, wind_all, pv_all, load_all, expected, sim_features_df[['renewable_cap_0','renewable_cap_1','N','max_energy','max_power']])
    df.set_index('description').to_csv(
        config['save_root']+settings['data']+('_Int_' if inputs['gen_cap'] else '_')+('Renewable'+str(profile_id)+'_' if 'profile_id' in settings else '_')+str(settings['day_num'])+'Days_'+str(settings['period'])+'HrsPerPeriod_{}.csv'.format(rps))
print("All Done!")
# Out:
# Rps :0.5
# 1th trial:  5.97 s
# 2th trial:  10.68 s
# 3th trial:  3.18 s
# 4th trial:  3.4 s
# 5th trial:  3.55 s
# 6th trial:  11.22 s
# 7th trial:  2.49 s
# 8th trial:  15.49 s
# 9th trial:  14.63 s
# 10th trial:  13.19 s
# 11th trial:  6.12 s
# 12th trial:  10.73 s
# 13th trial:  6.11 s
# 14th trial:  3.53 s
# 15th trial:  2.97 s
# 16th trial:  38.92 s
# 17th trial:  19.79 s
# 18th trial:  9.67 s
# 19th trial:  94.31 s
# 20th trial:  36.26 s
# 21th trial:  48.53 s
# 22th trial:  79.55 s
# 23th trial:  79.1 s
# 24th trial:  52.54 s
# 25th trial:  52.33 s
# 26th trial:  71.45 s
# 27th trial:  64.25 s
# 28th trial:  47.06 s
# 29th trial:  54.38 s
# 30th trial:  38.14 s
# 31th trial:  48.02 s
# 32th trial:  75.67 s
# 33th trial:  89.51 s
# 34th trial:  127.85 s
# 35th trial:  82.29 s
# 36th trial:  60.3 s
# 37th trial:  54.01 s
# 38th trial:  52.27 s
# 39th trial:  84.11 s
# 40th trial:  90.84 s
# 41th trial:  84.63 s
# 42th trial:  45.13 s
# 43th trial:  155.61 s
# 44th trial:  60.99 s
# 45th trial:  20.26 s
# 46th trial:  131.85 s
# 47th trial:  150.57 s
# 48th trial:  116.27 s
# 49th trial:  468.14 s
# 50th trial:  207.14 s
# 51th trial:  270.79 s
# 52th trial:  30.48 s
# 53th trial:  384.52 s
# 54th trial:  87.59 s
# 55th trial:  242.5 s
# 56th trial:  155.76 s
# 57th trial:  33.0 s
# 58th trial:  196.89 s
# 59th trial:  224.29 s
# 60th trial:  35.88 s
# 61th trial:  106.55 s
# 62th trial:  57.1 s
# 63th trial:  639.3 s
# 64th trial:  123.76 s
# 65th trial:  391.59 s
# 66th trial:  390.29 s
# 67th trial:  294.57 s
# 68th trial:  148.73 s
# 69th trial:  1115.58 s
# 70th trial:  338.46 s
# 71th trial:  181.06 s
# 72th trial:  149.69 s
# 73th trial:  127.78 s
# 74th trial:  203.01 s
# 75th trial:  236.78 s
# 76th trial:  268.9 s
# 77th trial:  82.4 s
# 78th trial:  835.01 s
# 79th trial:  440.03 s
# 80th trial:  475.92 s
# 81th trial:  705.16 s
# 82th trial:  862.65 s
# 83th trial:  327.83 s
# 84th trial:  1057.21 s
# 85th trial:  863.78 s
# 86th trial:  763.16 s
# 87th trial:  246.33 s
# 88th trial:  431.88 s
# 89th trial:  723.43 s
# 90th trial:  872.69 s
# Rps :0.55
# 1th trial:  4.81 s
# 2th trial:  6.68 s
# 3th trial:  20.94 s
# 4th trial:  21.06 s
# 5th trial:  5.21 s
# 6th trial:  25.43 s
# 7th trial:  5.11 s
# 8th trial:  16.78 s
# 9th trial:  8.2 s
# 10th trial:  42.07 s
# 11th trial:  6.19 s
# 12th trial:  15.73 s
# 13th trial:  9.27 s
# 14th trial:  9.1 s
# 15th trial:  3.92 s
# 44th trial:  29.48 s
# 45th trial:  48.9 s
# 46th trial:  184.07 s
# 47th trial:  54.18 s
# 48th trial:  139.12 s
# 49th trial:  158.31 s
# 50th trial:  183.07 s
# 51th trial:  60.5 s
# 52th trial:  37.02 s
# 53th trial:  183.64 s
# 54th trial:  116.08 s
# 55th trial:  210.1 s
# 56th trial:  31.86 s
# 57th trial:  230.77 s
# 58th trial:  187.65 s
# 59th trial:  211.92 s
# 60th trial:  116.81 s
# 61th trial:  266.9 s
# 62th trial:  68.6 s
# 63th trial:  113.1 s
# 64th trial:  155.16 s
# 65th trial:  316.3 s
# 66th trial:  150.64 s
# 67th trial:  65.67 s
# 68th trial:  233.6 s
# 69th trial:  218.38 s
# 70th trial:  225.47 s
# 71th trial:  361.27 s
# 72th trial:  78.81 s
# 73th trial:  263.23 s
# 74th trial:  211.82 s
# 75th trial:  159.64 s
# 76th trial:  396.64 s
# 77th trial:  75.12 s
# 78th trial:  332.56 s
# 79th trial:  672.94 s
# 80th trial:  224.97 s
# 81th trial:  423.35 s
# 82th trial:  69.16 s
# 83th trial:  1065.61 s
# 84th trial:  343.84 s
# 85th trial:  423.4 s
# 86th trial:  433.2 s
# 87th trial:  431.37 s
# 88th trial:  68.44 s
# 89th trial:  156.08 s
# 90th trial:  309.52 s
# Rps :0.9
# 1th trial:  6.82 s
# 2th trial:  6.9 s
# 3th trial:  6.84 s
# 4th trial:  9.74 s
# 5th trial:  7.51 s
# 6th trial:  7.63 s
# 7th trial:  5.68 s
# 8th trial:  7.6 s
# 9th trial:  5.84 s
# 10th trial:  6.66 s
# 11th trial:  14.76 s
# 12th trial:  6.76 s
# 13th trial:  5.37 s
# 14th trial:  8.6 s
# 15th trial:  6.6 s
# 16th trial:  15.28 s
# 17th trial:  12.0 s
# 18th trial:  16.85 s
# 19th trial:  18.75 s
# 20th trial:  20.26 s
# 21th trial:  20.12 s
# 22th trial:  10.88 s
# 23th trial:  11.58 s
# 24th trial:  8.81 s
# 25th trial:  9.42 s
# 26th trial:  22.07 s
# 27th trial:  15.06 s
# 28th trial:  11.51 s
# 29th trial:  14.13 s
# 30th trial:  49.59 s
# 31th trial:  41.46 s
# 32th trial:  26.83 s
# 33th trial:  37.54 s
# 34th trial:  31.06 s
# 35th trial:  32.29 s
# 36th trial:  29.06 s
# 37th trial:  30.21 s
# 38th trial:  27.14 s
# 39th trial:  93.76 s
# 40th trial:  98.05 s
# 41th trial:  113.67 s
# 42th trial:  33.75 s
# 43th trial:  45.29 s
# 44th trial:  31.49 s
# 45th trial:  28.5 s
# 46th trial:  176.75 s
# 47th trial:  50.19 s
# 48th trial:  47.14 s
# 49th trial:  145.47 s
# 50th trial:  147.88 s
# 51th trial:  53.83 s
# 52th trial:  151.9 s
# 53th trial:  208.05 s
# 54th trial:  71.97 s
# 55th trial:  47.25 s
# 56th trial:  39.08 s
# 57th trial:  38.03 s
# 58th trial:  71.57 s
# 59th trial:  166.68 s
# 60th trial:  47.49 s
# 61th trial:  188.0 s
# 62th trial:  79.59 s
# 63th trial:  145.11 s
# 64th trial:  164.62 s
# 65th trial:  112.21 s
# 66th trial:  51.34 s
