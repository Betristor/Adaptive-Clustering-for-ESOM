# %% [markdown]
# ### Basic global settings trials including ncluster, method and data used

# %%
import os
import json
import itertools
import pandas as pd
from functions import *
# %set_env GUROBI_HOME=/usr/local/gurobi/linux64
# Out:
# env: GUROBI_HOME=/usr/local/gurobi/linux64

# %%
with open('config.json', 'r') as f:
    config_all = json.loads(f.read())

config = config_all['Texas_7_years_1']
inputs = config['inputs']
settings = config['settings']
print(config)
pv_all = np.genfromtxt(
    os.path.join(config['root'], config['pv_path']), delimiter=',', filling_values=0)
wind_all = np.genfromtxt(
    os.path.join(config['root'], config['wind_path']), delimiter=',', filling_values=0)
load_all = np.genfromtxt(
    os.path.join(config['root'], config['load_path']), delimiter=',', filling_values=0)  # Data load
# Out:
# {'root': '/home/jupyter-zyh/Gnhe/data/Texas/', 'save_root': '/home/jupyter-zyh/Gnhe/analysis_setting/centroid/Integer/', 'pv_path': 'pv_data_Texas.csv', 'wind_path': 'wind_data_Texas.csv', 'load_path': 'power_demand_Texas.csv', 'note_1': 'This property is set to indicate what are above properties for path. No need to change.', 'inputs': {'c_bat': 200000, 'c_bat_power': 70000, 'c_pv': 1000000, 'c_wind': 1500000, 'c_gen_inv': 1000000, 'c_gen_a': 0.1, 'c_gen_b': 30, 'up_time': 6, 'down_time': 6, 'energy_cap': 200, 'power_cap': 200, 'gen_cap': 1, 'mdc': 50, 'effi': 0.9, 'rps': 0.8, 'note_2': 'This property is set to indicate what are above properties for model. Change with model parameters.', 'solver': 1, 'print_log': 0, 'timelimit': 210240, 'note_3': 'This property is set to indicate what are above properties for solver. No need to change.'}, 'settings': {'data': 'Texas', 'profile_id': 1, 'day_num': 1092, 'period': 168, 'normalize': False, 'feature_set': ['renewable_cap', 'N', 'max_energy', 'max_power', 'total_cost']}, 'note_4': 'This property is set to indicate what are above properties for settings. Change with data and method.', 'ranges': {'methods': ['kmeans', 'single', 'ward', 'average', 'complete'], 'trials': ['hourly', 'combined'], 'nclusters': [5, 10, 15, 20, 25, 30]}, 'note_5': 'This property is set to indicate what are above properties for global setings. Change with global settings.'}

# %%
day_num = settings['day_num']
time_set = np.arange(24*day_num)  # Time horizon
if 'profile_id' in settings:
    profile_id = settings['profile_id']
    renewable = [wind_all[time_set, profile_id],pv_all[time_set, profile_id]]
else:
    # Denote that first profile is used and no other profile exists.
    profile_id = -1
    renewable = [wind_all[time_set], pv_all[time_set]]
load = load_all[time_set]*100  # Data extract

# %%
for rps in [0.5,0.55,0.6,0.65,0.85,0.9,0.95]:
    print("Rps :" + str(rps))
    inputs['rps'] = rps
    config['inputs'] = inputs
    expected = pd.read_csv('/home/jupyter-zyh/Gnhe/benchmark/Integer/Texas/profile-{}/expected/expected_1092_rps_{}_1e-3.csv'.format(profile_id,rps), index_col=0).loc[0,:].to_dict()
    sim_features_df = pd.read_csv('/home/jupyter-zyh/Gnhe/benchmark/Integer/Texas/profile-{}/features/features_1092_rps_{}_1e-3.csv'.format(profile_id,rps), index_col=0)
    df = run_trials(config, wind_all, pv_all, load_all, expected, sim_features_df[['renewable_cap_0','renewable_cap_1','N','max_energy','max_power']])
    df.set_index('description').to_csv(
        config['save_root']+settings['data']+('_Int_' if inputs['gen_cap'] else '_')+('Renewable'+str(profile_id)+'_' if 'profile_id' in settings else '_')+str(settings['day_num'])+'Days_'+str(settings['period'])+'HrsPerPeriod_{}.csv'.format(rps))
print("All Done!")
# Out:
# Rps :0.5
# 1th trial:  5.98 s
# 2th trial:  4.39 s
# 3th trial:  18.45 s
# 4th trial:  11.13 s
# 5th trial:  3.46 s
# 6th trial:  3.69 s
# 7th trial:  22.12 s
# 8th trial:  3.72 s
# 9th trial:  5.39 s
# 10th trial:  3.88 s
# 11th trial:  6.06 s
# 12th trial:  4.74 s
# 13th trial:  16.69 s
# 14th trial:  17.49 s
# 15th trial:  20.51 s
# 16th trial:  5.99 s
# 17th trial:  23.27 s
# 18th trial:  3.79 s
# 19th trial:  14.96 s
# 20th trial:  3.83 s
# 21th trial:  119.91 s
# 22th trial:  12.98 s
# 23th trial:  14.63 s
# 24th trial:  76.39 s
# 25th trial:  107.04 s
# 26th trial:  102.52 s
# 27th trial:  104.29 s
# 28th trial:  119.75 s
# 29th trial:  13.79 s
# 30th trial:  53.31 s
# 31th trial:  17.32 s
# 32th trial:  127.55 s
# 33th trial:  95.31 s
# 34th trial:  80.57 s
# 35th trial:  13.97 s
# 36th trial:  92.75 s
# 37th trial:  159.63 s
# 38th trial:  67.51 s
# 39th trial:  128.43 s
# 40th trial:  76.67 s
# 41th trial:  17.28 s
# 42th trial:  186.11 s
# 43th trial:  244.6 s
# 44th trial:  55.67 s
# 45th trial:  228.13 s
# 46th trial:  79.62 s
# 47th trial:  132.24 s
# 48th trial:  86.27 s
# 49th trial:  424.2 s
# 50th trial:  144.77 s
# 51th trial:  197.9 s
# 52th trial:  31.21 s
# 53th trial:  76.29 s
# 54th trial:  19.45 s
# 55th trial:  273.06 s
# 56th trial:  110.87 s
# 57th trial:  24.71 s
# 58th trial:  332.23 s
# 59th trial:  197.96 s
# 60th trial:  146.65 s
# 61th trial:  476.78 s
# 62th trial:  713.53 s
# 63th trial:  56.02 s
# 64th trial:  384.69 s
# 65th trial:  48.31 s
# 66th trial:  359.84 s
# 67th trial:  143.02 s
# 68th trial:  76.75 s
# 69th trial:  232.22 s
# 70th trial:  331.98 s
# 71th trial:  353.45 s
# 72th trial:  685.26 s
# 73th trial:  270.8 s
# 74th trial:  274.16 s
# 75th trial:  224.48 s
# 76th trial:  371.28 s
# 77th trial:  156.68 s
# 78th trial:  356.53 s
# 79th trial:  286.0 s
# 80th trial:  455.88 s
# 81th trial:  252.74 s
# 82th trial:  355.83 s
# 83th trial:  53.97 s
# 84th trial:  113.09 s
# 85th trial:  346.84 s
# 86th trial:  230.24 s
# 87th trial:  586.91 s
# 88th trial:  493.96 s
# 89th trial:  1719.16 s
# 90th trial:  238.23 s
# 91th trial:  591.52 s
# 92th trial:  573.58 s
# 93th trial:  206.93 s
# 94th trial:  118.99 s
# 95th trial:  533.44 s
# 96th trial:  440.63 s
# 97th trial:  430.32 s
# 98th trial:  692.3 s
# 99th trial:  1439.32 s
# 100th trial:  210.7 s
# 101th trial:  718.12 s
# 102th trial:  572.2 s
# 103th trial:  84.66 s
# 104th trial:  216.29 s
# 105th trial:  994.09 s
# 106th trial:  1370.79 s
# 107th trial:  541.69 s
# 108th trial:  168.28 s
# 109th trial:  2314.97 s
# 110th trial:  1694.76 s
# 111th trial:  904.04 s
# 112th trial:  1987.29 s
# 113th trial:  202.5 s
# 114th trial:  665.29 s
# 115th trial:  722.99 s
# 116th trial:  1717.68 s
# 117th trial:  284.44 s
# 118th trial:  1359.38 s
# 119th trial:  2892.64 s
# 120th trial:  447.21 s
# Rps :0.55
# 1th trial:  24.14 s
# 2th trial:  4.7 s
# 3th trial:  14.05 s
# 4th trial:  5.86 s
# 5th trial:  3.87 s
# 6th trial:  13.37 s
# 7th trial:  9.5 s
# 8th trial:  3.76 s
# 9th trial:  8.53 s
# 10th trial:  4.62 s
# 11th trial:  5.41 s
# 12th trial:  5.46 s
# 13th trial:  7.53 s
# 14th trial:  4.66 s
# 15th trial:  3.45 s
# 16th trial:  6.29 s
# 17th trial:  14.74 s
# 18th trial:  11.42 s
# 19th trial:  9.16 s
# 20th trial:  4.91 s
# 21th trial:  16.88 s
# 22th trial:  17.06 s
# 23th trial:  13.8 s
# 24th trial:  99.71 s
# 25th trial:  144.5 s
# 26th trial:  51.16 s
# 27th trial:  33.41 s
# 28th trial:  64.16 s
# 29th trial:  21.68 s
# 30th trial:  14.05 s
# 31th trial:  24.4 s
# 32th trial:  14.41 s
# 33th trial:  15.47 s
# 34th trial:  88.17 s
# 35th trial:  133.69 s
# 36th trial:  71.71 s
# 37th trial:  62.55 s
# 38th trial:  87.93 s
# 39th trial:  105.5 s
# 40th trial:  70.81 s
# 41th trial:  214.71 s
# 42th trial:  381.02 s
# 43th trial:  13.74 s
# 44th trial:  179.46 s
# 45th trial:  218.55 s
# 46th trial:  88.12 s
# 47th trial:  38.84 s
# 48th trial:  180.56 s
# 49th trial:  34.94 s
# 50th trial:  191.13 s
# 51th trial:  182.99 s
# 52th trial:  46.15 s
# 53th trial:  14.64 s
# 54th trial:  119.12 s
# 55th trial:  264.11 s
# 56th trial:  52.61 s
# 57th trial:  328.3 s
# 58th trial:  87.81 s
# 59th trial:  97.99 s
# 60th trial:  95.01 s
# 61th trial:  749.56 s
# 62th trial:  288.53 s
# 63th trial:  178.6 s
# 64th trial:  114.4 s
# 65th trial:  392.49 s
# 66th trial:  98.5 s
# 67th trial:  445.05 s
# 68th trial:  100.09 s
# 69th trial:  176.42 s
# 70th trial:  295.67 s
# 71th trial:  259.06 s
# 72th trial:  541.14 s
# 73th trial:  284.29 s
# 74th trial:  179.91 s
# 75th trial:  491.96 s
# 76th trial:  440.16 s
# 77th trial:  747.42 s
# 78th trial:  197.74 s
# 79th trial:  107.65 s
# 80th trial:  240.49 s
# 81th trial:  733.94 s
# 82th trial:  309.34 s
# 83th trial:  153.62 s
# 84th trial:  258.79 s
# 85th trial:  706.2 s
# 86th trial:  536.31 s
# 87th trial:  1876.85 s
# 88th trial:  536.37 s
# 89th trial:  1371.39 s
# 90th trial:  154.09 s
# 91th trial:  1615.73 s
# 92th trial:  367.79 s
# 93th trial:  82.47 s
# 94th trial:  80.82 s
# 95th trial:  558.2 s
# 96th trial:  1357.91 s
# 97th trial:  1731.39 s
# 98th trial:  775.41 s
# 99th trial:  436.27 s
# 100th trial:  63.83 s
# 101th trial:  1110.25 s
# 102th trial:  215.03 s
# 103th trial:  345.18 s
# 104th trial:  290.46 s
# 105th trial:  460.97 s
# 106th trial:  923.64 s
# 107th trial:  5220.98 s
# 108th trial:  981.81 s
# 109th trial:  3477.23 s
# 110th trial:  422.84 s
# 111th trial:  331.73 s
# 112th trial:  2541.21 s
# 113th trial:  445.42 s
# 114th trial:  237.12 s
# 115th trial:  1063.01 s
# 116th trial:  389.27 s
# 117th trial:  1678.59 s
# 118th trial:  440.03 s
# 119th trial:  1000.64 s
# 120th trial:  996.52 s
# Rps :0.6
# 1th trial:  29.32 s
# 2th trial:  7.47 s
# 3th trial:  8.71 s
# 4th trial:  8.74 s
# 5th trial:  7.44 s
# 6th trial:  28.38 s
# 7th trial:  41.33 s
# 8th trial:  6.13 s
# 9th trial:  32.89 s
# 10th trial:  7.35 s
# 11th trial:  7.84 s
# 12th trial:  6.29 s
# 13th trial:  7.73 s
# 14th trial:  7.15 s
# 15th trial:  32.15 s
# 16th trial:  6.15 s
# 17th trial:  8.89 s
# 18th trial:  7.11 s
# 19th trial:  30.86 s
# 20th trial:  6.46 s
# 21th trial:  149.16 s
# 22th trial:  155.81 s
# 23th trial:  10.91 s
# 24th trial:  19.67 s
# 25th trial:  23.26 s
# 26th trial:  212.95 s
# 27th trial:  88.02 s
# 28th trial:  119.88 s
# 29th trial:  308.58 s
# 30th trial:  51.14 s
# 31th trial:  137.14 s
# 32th trial:  12.05 s
# 33th trial:  42.26 s
# 34th trial:  16.75 s
# 35th trial:  192.31 s
# 36th trial:  97.8 s
# 37th trial:  160.85 s
# 38th trial:  141.95 s
# 39th trial:  179.33 s
# 40th trial:  47.78 s
# 41th trial:  438.2 s
# 42th trial:  37.5 s
# 43th trial:  55.11 s
# 44th trial:  399.06 s
# 45th trial:  1055.54 s
# 46th trial:  337.95 s
# 47th trial:  114.67 s
# 48th trial:  134.69 s
# 49th trial:  243.43 s
# 50th trial:  125.8 s
# 51th trial:  261.18 s
# 52th trial:  869.85 s
# 53th trial:  32.93 s
# 54th trial:  416.23 s
# 55th trial:  634.85 s
# 56th trial:  37.5 s
# 57th trial:  201.18 s
# 58th trial:  184.39 s
# 59th trial:  190.02 s
# 60th trial:  169.16 s
# 61th trial:  931.89 s
# 62th trial:  70.32 s
# 63th trial:  176.55 s
# 64th trial:  96.28 s
# 65th trial:  347.06 s
# 66th trial:  558.6 s
# 67th trial:  205.62 s
# 68th trial:  229.72 s
# 69th trial:  1601.93 s
# 70th trial:  689.52 s
# 71th trial:  403.36 s
# 72th trial:  602.56 s
# 73th trial:  39.88 s
# 74th trial:  285.47 s
# 75th trial:  365.29 s
# 76th trial:  161.82 s
# 77th trial:  372.06 s
# 78th trial:  568.52 s
# 79th trial:  904.26 s
# 80th trial:  342.94 s
# 81th trial:  884.08 s
# 82th trial:  1061.37 s
# 83th trial:  549.48 s
# 84th trial:  459.03 s
# 85th trial:  1250.01 s
# 86th trial:  1884.95 s
# 87th trial:  412.34 s
# 88th trial:  1672.84 s
# 89th trial:  379.3 s
# 90th trial:  244.48 s
# 91th trial:  735.71 s
# 92th trial:  605.47 s
# 93th trial:  521.33 s
# 94th trial:  88.62 s
# 95th trial:  798.22 s
# 96th trial:  242.58 s
# 97th trial:  326.54 s
# 98th trial:  818.75 s
# 99th trial:  543.87 s
# 100th trial:  300.19 s
# 101th trial:  1016.18 s
# 102th trial:  696.12 s
# 103th trial:  574.76 s
# 104th trial:  1090.26 s
# 105th trial:  317.38 s
# 106th trial:  809.29 s
# 107th trial:  415.76 s
# 108th trial:  593.64 s
# 109th trial:  2776.71 s
# 110th trial:  726.72 s
# 111th trial:  806.58 s
# 112th trial:  67.56 s
# 113th trial:  459.15 s
# 114th trial:  429.18 s
# 115th trial:  987.49 s
# 116th trial:  429.25 s
# 117th trial:  440.45 s
# 118th trial:  54.93 s
# 119th trial:  3426.09 s
# 120th trial:  415.0 s
# Rps :0.65
# 1th trial:  11.84 s
# 2th trial:  6.98 s
# 3th trial:  7.7 s
# 4th trial:  24.69 s
# 5th trial:  25.27 s
# 6th trial:  7.99 s
# 7th trial:  29.26 s
# 8th trial:  32.82 s
# 9th trial:  11.37 s
# 10th trial:  30.35 s
# 11th trial:  7.23 s
# 12th trial:  20.02 s
# 13th trial:  6.7 s
# 14th trial:  29.88 s
# 15th trial:  18.26 s
# 16th trial:  23.29 s
# 17th trial:  50.39 s
# 18th trial:  38.71 s
# 19th trial:  25.31 s
# 20th trial:  6.96 s
# 21th trial:  140.8 s
# 22th trial:  20.29 s
# 23th trial:  17.12 s
# 24th trial:  13.84 s
# 25th trial:  20.85 s
# 26th trial:  57.37 s
# 27th trial:  66.18 s
# 28th trial:  44.22 s
# 29th trial:  75.92 s
# 30th trial:  79.86 s
# 31th trial:  65.85 s
# 32th trial:  112.48 s
# 33th trial:  22.77 s
# 34th trial:  26.52 s
# 35th trial:  32.34 s
# 36th trial:  85.04 s
# 37th trial:  112.64 s
# 38th trial:  45.63 s
# 39th trial:  83.31 s
# 40th trial:  66.65 s
# 41th trial:  247.19 s
# 42th trial:  285.92 s
# 43th trial:  152.48 s
# 44th trial:  104.02 s
# 45th trial:  39.82 s
# 46th trial:  203.43 s
# 47th trial:  84.73 s
# 48th trial:  114.57 s
# 49th trial:  532.99 s
# 50th trial:  272.48 s
# 51th trial:  323.94 s
# 52th trial:  123.29 s
# 53th trial:  144.87 s
# 54th trial:  32.89 s
# 55th trial:  184.54 s
# 56th trial:  316.08 s
# 57th trial:  31.16 s
# 58th trial:  137.24 s
# 59th trial:  198.11 s
# 60th trial:  71.43 s
# 61th trial:  600.7 s
# 62th trial:  251.89 s
# 63th trial:  244.58 s
# 64th trial:  154.81 s
# 65th trial:  31.67 s
# 66th trial:  294.86 s
# 67th trial:  250.7 s
# 68th trial:  433.58 s
# 69th trial:  279.15 s
# 70th trial:  184.81 s
# 71th trial:  407.25 s
# 72th trial:  319.45 s
# 73th trial:  92.05 s
# 74th trial:  610.99 s
# 75th trial:  234.29 s
# 77th trial:  161.79 s
# 78th trial:  246.2 s
# 79th trial:  185.59 s
# 80th trial:  448.51 s
# 81th trial:  554.61 s
# 82th trial:  905.02 s
# 83th trial:  876.1 s
# 84th trial:  71.57 s
# 85th trial:  99.59 s
# 86th trial:  803.63 s
# 87th trial:  275.49 s
# 88th trial:  660.56 s
# 89th trial:  385.26 s
# 90th trial:  502.92 s
# 91th trial:  444.46 s
# 92th trial:  994.67 s
# 93th trial:  751.94 s
# 94th trial:  290.39 s
# 95th trial:  389.5 s
# 96th trial:  192.0 s
# 97th trial:  553.44 s
# 98th trial:  309.57 s
# 99th trial:  506.71 s
# 100th trial:  649.6 s
# 101th trial:  526.97 s
# 102th trial:  1192.82 s
# 103th trial:  621.72 s
# 104th trial:  609.6 s
# 105th trial:  1078.0 s
# 106th trial:  1417.82 s
# 107th trial:  844.27 s
# 108th trial:  508.56 s
# 109th trial:  869.78 s
# 110th trial:  899.74 s
# 111th trial:  962.51 s
# 112th trial:  750.71 s
# 113th trial:  293.61 s
# 114th trial:  403.13 s
# 115th trial:  389.03 s
# 116th trial:  103.21 s
# 117th trial:  1030.84 s
# 118th trial:  672.31 s
# 119th trial:  306.54 s
# 120th trial:  551.15 s
# Rps :0.7
# 1th trial:  6.61 s
# 2th trial:  5.53 s
# 3th trial:  4.67 s
# 4th trial:  6.09 s
# 5th trial:  13.28 s
# 6th trial:  12.26 s
# 7th trial:  18.65 s
# 8th trial:  7.01 s
# 9th trial:  18.81 s
# 10th trial:  16.89 s
# 11th trial:  18.64 s
# 12th trial:  16.24 s
